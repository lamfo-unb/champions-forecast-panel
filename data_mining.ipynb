# %% [markdown]
# A primeira etapa deve ser o import das principais bibliotecas utilizadas para web scrapping

# %%
import requests
import re
from bs4 import BeautifulSoup as bs

# %%
fut_365_url = "https://www.futebol365.pt/competicao/26/?edition=2018&competition_phase=Fase+de+grupos&group=all&phase_round=all"
fut_365_page = requests.get(fut_365_url)
soup = bs(fut_365_page.content, 'html.parser')

# %%
champions_18_19_teams = []
teams_list = soup.select("body > div.ink-grid.all-container > section.left-column-group > div > table:nth-child(9) > tbody > tr > td.align-left")

print(teams_list)

# for team in teams_list:
#   team_name = team.text
#   print(team_name)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-6-811e4d529921> in <module>()
#       1 champions_18_19_teams = []
# ----> 2 teams_list = soup.select("body > div.ink-grid.all-container > section.left-column-group > div > table:nth-child(9) > tbody > tr > td.align-left")
#       3
#       4 print(teams_list)
#       5
#
# /usr/local/lib/python3.6/dist-packages/bs4/element.py in select(self, selector, _candidate_generator, limit)
#    1607                     print("    Running candidate generator on %s %s" % (
#    1608                         tag.name, repr(tag.attrs)))
# -> 1609                 for candidate in _use_candidate_generator(tag):
#    1610                     if not isinstance(candidate, Tag):
#    1611                         continue
#
# /usr/local/lib/python3.6/dist-packages/bs4/element.py in recursive_select(tag)
# ...
